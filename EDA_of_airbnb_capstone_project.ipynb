# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/AirBnb Booking Analysis
# ##### **Contribution**    - Individual
# ##### **Joyal shaji **

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the bustling metropolis of New York City, Airbnb has become a cornerstone of the hospitality industry, offering travelers unique accommodations and hosts lucrative opportunities. Our project delves into an extensive Exploratory Data Analysis (EDA) of the Airbnb NYC 2019 dataset, aiming to uncover insights into listing dynamics, host behaviors, and guest preferences within the vibrant cityscape.
#
# The dataset encapsulates a wealth of information pertaining to Airbnb listings in New York City during the year 2019. It encompasses a diverse array of attributes, including listing details, host characteristics, neighborhood demographics, and booking metrics. With this comprehensive dataset at our disposal, our objective is to conduct a comprehensive exploration of various factors shaping the Airbnb ecosystem in one of the world's most iconic cities.
#
# Our analysis commences by elucidating basic statistics and distributions of key numeric variables such as listing prices, minimum nights required for booking, number of reviews, and listing availability. Utilizing histograms, box plots, and summary statistics, we gain initial insights into the central tendencies, spreads, and outliers present within the dataset, laying the groundwork for deeper investigation.
#
# Subsequently, we embark on an exploration of relationships between different variables through correlation analysis and visualizations. By employing scatter plots, pair plots, and correlation matrices, we endeavor to identify patterns and dependencies between variables. For instance, we scrutinize correlations between listing prices and availability, number of reviews and host listings count, and other pertinent factors. Insights gleaned from these analyses furnish valuable information regarding host behaviors, guest preferences, and market trends within the Airbnb platform.
#
# Furthermore, we delve into spatial patterns and trends by analyzing listings across various neighborhoods and boroughs of New York City. Leveraging maps, heatmaps, and geographical visualizations, we gain insights into the distribution of listings, average prices, and popularity across different locales. Understanding regional disparities in pricing, demand, and listing characteristics is pivotal in informing strategic decision-making for hosts and facilitating optimal guest experiences.
#
# Moreover, temporal dynamics and seasonality are scrutinized by analyzing booking availability and review counts over time. Through line plots, time series analysis, and seasonal decomposition techniques, we uncover patterns in booking activity, peak seasons, and fluctuations in demand throughout the year. These insights are invaluable for hosts in devising pricing strategies, managing inventory, and capitalizing on revenue opportunities.
#
# In addition to quantitative analysis, qualitative aspects such as room types, host profiles, and neighborhood preferences are explored. Employing text analysis, word clouds, and sentiment analysis techniques, we unveil prevalent themes, sentiments, and preferences expressed in listing descriptions, reviews, and host profiles.
#
# In summation, our EDA of the Airbnb NYC 2019 dataset endeavors to provide a holistic understanding of the platform's dynamics within the multifaceted urban landscape of New York City. By unraveling trends, patterns, and correlations inherent within the data, we contribute to informed decision-making, strategic planning, and enhanced user experiences within the dynamic realm of Airbnb in the Big Apple.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Airbnb market in New York City is a dynamic and rapidly evolving ecosystem, presenting various challenges and opportunities for hosts, guests, policymakers, and industry stakeholders. To navigate this complex landscape effectively, it is essential to conduct a comprehensive analysis of the Airbnb NYC 2019 dataset to uncover insights and address key questions pertinent to the market's dynamics. Our problem statement revolves around exploring the trends, behaviors, preferences, and spatial-temporal patterns within the Airbnb ecosystem to inform decision-making and enhance understanding.
#
# The analysis seeks to address fundamental questions about market trends, host behaviors, guest preferences, spatial dynamics, temporal fluctuations, and policy implications within the New York City Airbnb market. Understanding how listing prices, availability, and demand vary over time and across different neighborhoods is crucial for both hosts and guests to optimize their strategies and experiences. Additionally, delving into host characteristics, such as the number of listings managed and their correlation with listing popularity and pricing strategies, provides insights into host behaviors and market competitiveness.
#
# Moreover, uncovering guest preferences, including factors influencing booking decisions such as room type, location, and amenities, is paramount for enhancing guest satisfaction and experience. Spatial analysis offers valuable insights into geographical patterns and disparities, shedding light on neighborhood dynamics, listing characteristics, and pricing dynamics. Furthermore, examining temporal dynamics, such as seasonal trends, peak periods, and events impacting demand and pricing, provides actionable insights for hosts and policymakers.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to leverage insights gleaned from the Airbnb NYC 2019 dataset to drive strategic decision-making, optimize operational efficiencies, and enhance user satisfaction within the Airbnb ecosystem in New York City. Through a thorough analysis of the dataset, our aim is to achieve several specific business objectives that benefit hosts, guests, policymakers, and industry stakeholders alike.
#
# Firstly, we seek to empower hosts with actionable insights into market trends, pricing strategies, and guest preferences. By understanding demand dynamics and competitive positioning, hosts can optimize their listing strategies to maximize occupancy rates and revenue generation. Additionally, providing guests with comprehensive information about listing attributes, neighborhood characteristics, and amenities enhances their booking experiences, leading to higher satisfaction levels and positive reviews.
#
# Moreover, this project aims to inform policymakers and regulatory bodies about the impact of Airbnb on housing affordability, neighborhood dynamics, and community well-being. By offering evidence-based insights, we support the development of effective regulatory frameworks that balance the interests of hosts, guests, and local communities while promoting responsible participation within the Airbnb ecosystem.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Coulmn names

# %%
column_names=df.columns.tolist()
print(column_names)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicates_by_column = {}

for column in df.columns:
    duplicates_count = df[column].duplicated().sum()
    duplicates_by_column[column] = duplicates_count

print("Duplicate values count for each column:")
print(duplicates_by_column)
# Out:
# Duplicate values count for each column:
# {'id': 0, 'name': 989, 'host_id': 11438, 'host_name': 37442, 'neighbourhood_group': 48890, 'neighbourhood': 48674, 'latitude': 29847, 'longitude': 34177, 'room_type': 48892, 'price': 48221, 'minimum_nights': 48786, 'number_of_reviews': 48501, 'last_review': 47130, 'reviews_per_month': 47957, 'calculated_host_listings_count': 48848, 'availability_365': 48529}

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values_count = df.isna().sum()
missing_values_count
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
import missingno as msno
msno.bar(df)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# From the above analysis i can say that there is 48895 rows and 16 columns are present in our data set, and we can find duplicate values in almost all the columns except in id.
# And in last_review,reviews_per_month column we can find too many missing values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
column_names=df.columns.tolist()
print(column_names)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1-id: Identifier for each Airbnb listing.
# 2-name: Name of the Airbnb listing.
# 3-host_id: Identifier for the host of the listing.
# 4-host_name: Name of the host of the listing.
# 5-neighbourhood_group: Grouping of neighbourhoods (e.g., borough in a city).
# 6-neighbourhood: Specific neighbourhood where the listing is located.
# 7-latitude: Latitude coordinate of the listing's location.
# 8-longitude: Longitude coordinate of the listing's location.
# 9-room_type: Type of room offered in the listing (e.g., entire home/apartment, private room, shared room).
# 10-price: Price per night for the listing.
# 11-minimum_nights: Minimum number of nights required for booking the listing.
# 12-number_of_reviews: Total number of reviews for the listing.
# 13-last_review: Date of the last review for the listing.
# 14-reviews_per_month: Average number of reviews the listing receives per month.
# 15-calculated_host_listings_count: Number of listings that the host has on Airbnb.
# 16-availability_365: Number of days the listing is available for booking within a year.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
  unique_values=df[column].unique()
  print(f"unique values of {column}:")
  print(unique_values)
  print()
# Out:
# unique values of id:
# [    2539     2595     3647 ... 36485431 36485609 36487245]
#
# unique values of name:
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
#
# unique values of host_id:
# [     2787      2845      4632 ... 274321313  23492952  68119814]
#
# unique values of host_name:
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
#
# unique values of neighbourhood_group:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
#
# unique values of neighbourhood:
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
values_to_fill={'name':'no name','host_name':'no host name'}
df.fillna(value=values_to_fill,inplace=True)

# %%
columns_to_drop = ['latitude', 'longitude', 'last_review','reviews_per_month']
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
column_names=df.columns.tolist()
print(column_names)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood        room_type  \
# 0         John            Brooklyn          Kensington     Private room
# 1     Jennifer           Manhattan             Midtown  Entire home/apt
# ...

# %%
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.shape
# Out:
# (48895, 12)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Here initialy i found two columns 'name' and 'hostname' with null values so i replaced the missing value of name column with no name and missing value of host name with no host name. And then i found latitude and longitude column are not very much important, and also last review and reviews per month have too many missing values so i used to remove all the four columns from the dataset.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Averege price by neighbourhood_group
neighbourhood_group_avg_price=df.groupby('neighbourhood_group')['price'].mean()
neighbourhood_group_avg_price_sorted=neighbourhood_group_avg_price.sort_values(ascending=False)
neighbourhood_group_avg_price_sorted
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 6))
neighbourhood_group_avg_price_sorted.plot(kind='bar', color='skyblue')
plt.title('Average Price by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a vertical bar chart because it's a suitable choice for comparing the average price across different neighborhood groups. Each bar represents a neighborhood group, making it easy to compare the average prices visually. Additionally, sorting the bars in descending order allows viewers to quickly identify which neighborhood group has the highest average price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. It's evident that there are significant price disparities among different neighborhood groups. Some groups likely have higher average prices compared to others.
# 2. Neighborhood groups with higher average prices might be considered more affluent or upscale areas, while those with lower average prices may be perceived as more affordable or less prestigious.
# 3.The chart can provide insights into market segmentation. For example, certain neighborhood groups may cater to luxury or high-end markets, while others may attract budget-conscious buyers or renters.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it helps for creating a positive business impact.
# I did not feel any insights from this chart that leads to negative growth. From this chart I can say that if a user who wish to locate to some upscale area this cart migth be helpfull.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
max_listings_count_by_host_neighbourhood = df.groupby(['host_name', 'neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
sorted_max_listings_count_by_host_neighbourhood = max_listings_count_by_host_neighbourhood.sort_values(by='calculated_host_listings_count', ascending=False)
sorted_max_listings_count_by_host_neighbourhood.head(10)
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                             327
# 1833          Blueground            Brooklyn                             232
# 1834          Blueground           Manhattan                             232
# 7275                Kara           Manhattan                             121
# 7479              Kazuya           Manhattan                             103
# 7480              Kazuya              Queens                             103
# 7478              Kazuya            Brooklyn                             103
# 6540      Jeremy & Laura           Manhattan                              96
# 13216             Sonder           Manhattan                              96
# 2901   Corporate Housing           Manhattan                              91

# %%
plt.figure(figsize=(10, 6))
plt.bar(sorted_max_listings_count_by_host_neighbourhood['host_name'][:10],
        sorted_max_listings_count_by_host_neighbourhood['calculated_host_listings_count'][:10],
        color='skyblue')
plt.xlabel('Host Name and Neighbourhood Group')
plt.ylabel('Max Calculated Host Listings Count')
plt.title('Top 10 Hosts by Max Listings Count in Each Neighbourhood Group')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a vertical bar chart because it's a suitable choice for grouping the host name and neighborhood groups and finding the max of host listing count.Each bar represents host name making it easy to compare the host listing count visually.additinally arranging it in the desecnding order helps users to identify which host has higher listing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here I found the host sonder nyc have made higher number of listing in airbnb in the area Manhattan followed by Blueground in Brooklyn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes from the above chart we can clearly say that sonder nyc had made more number of listing when compared with other hosts.But it does not mean sonder nyc had made more users in airbnb.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(10,6))
plt.scatter(df['price'],df['number_of_reviews'],color='green')
plt.xlabel('price')
plt.ylabel('number of reviews')
plt.title('number of reviews vs price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here scatter plot helps to understand the relationship between two contineous variables that is number of reviews vs price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# from number of reviews we can say that, if there is more number of reviews present in any area ,then there is more number of users in that area.
# So by seeing the above chart we can clearly say that more number of users are using the neigbhourhood were price is less.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes this helps for creating a positve business impact.
# when considering negative growth we can say that only less number of users are preferd to stay in room type or neighbourhood were price is more.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
sns.violinplot(hue='room_type', y='number_of_reviews', data=df, palette='pastel')
plt.xlabel('Room Type')
plt.ylabel('Average Number of Reviews')
plt.title('Average Number of Reviews by Room Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  violin plot is a type of graphical representation that combines the features of a box plot and a kernel density plot. It's often used to visualize the distribution of a numeric variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart i found like more number of users are prefferd to stay in a private room when compared with entire room or appartment and shared room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes the above chart helps creating a positve business impact
# one of my fiunding is that we can suggets the host to list more on private rooms rather than entire rooms or shared rooms.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
room_type_counts = df['room_type'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Room Type Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In the context of room type distribution in an Airbnb dataset, a pie chart can be used to visually represent the proportion of each room type among all listings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can say that 52 percent of the listing are entire home or apt and 45.7 percent is private rooms and remaining 2.5 percent is shared rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it gained some positive business impact one thing i observed from this cahrt and above chart is the distribution of entire home or appartment is more and required users is less,were the users are more in private rooms. And also the distribution of shared rooms is very less but users are almost nearly to entire home or appartment.
# from this we can say that we have to reduce the entir home disstribution and increase shared rooms and private rooms.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
price_room_type_neigh_group=df.groupby(['neighbourhood_group','room_type'])['price'].max().reset_index()
sorted_price_room_type_neigh_group=price_room_type_neigh_group.sort_values(by='price',ascending=False)
sorted_price_room_type_neigh_group.head(10)
# Out:
#    neighbourhood_group        room_type  price
# 3             Brooklyn  Entire home/apt  10000
# 6            Manhattan  Entire home/apt  10000
# 10              Queens     Private room  10000
# 7            Manhattan     Private room   9999
# 4             Brooklyn     Private room   7500
# 12       Staten Island  Entire home/apt   5000
# 9               Queens  Entire home/apt   2600
# 1                Bronx     Private room   2500
# 11              Queens      Shared room   1800
# 0                Bronx  Entire home/apt   1000

# %%
top_10 = sorted_price_room_type_neigh_group.head(10)

# Plotting the bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(top_10)), top_10['price'], color='skyblue')
plt.xlabel('Combination (Neighbourhood Group - Room Type)')
plt.ylabel('Maximum Price')
plt.title('Top 10 Combinations with Highest Maximum Prices')
plt.xticks(range(len(top_10)), [f"{group} - {room}" for group, room in zip(top_10['neighbourhood_group'], top_10['room_type'])], rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the specific chart, which is a bar chart representing the top 10 combinations of neighborhood groups and room types with the highest maximum prices.
# The chart focuses on highlighting the top performers or outliers within the dataset, which in this case are the combinations with the highest maximum prices. This helps draw attention to significant data points that might be of particular interest to viewers, such as expensive or luxurious accommodations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart i found the entire home or appartment in brooklyn and manhattan region have maximum price when compared with other room types avilable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As we can see the entire home or appartment has more price so the usage of this is less and more people are using a private rooms.
# And from the previous chart we observed that more people wish to stay in less priced areas so again listing more entire home or appartment will lead to negative growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10, 6))
plt.scatter(df['availability_365'], df['price'], alpha=0.5, color='skyblue')
plt.xlabel('Availability (in days)')
plt.ylabel('price')
plt.title('Availability vs. price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I choose scatter plot because I want to see the distribution of all the points clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I found the low cost rooms are avilable for almost all the days And the rooms with high rent is only available in some of the days in a year, this might be some specific season that atracts the users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here by this chart i observed like if the availability is less then the demand will increase as a reason the price also increased.
# some of the negative impact is like if the availability is less then demand is more so only some people will get it, remaining people will miss the opertunity to use that resort or a room.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10, 6))
plt.hist(df['number_of_reviews'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Reviews')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram provides a clear representation of how the number of reviews is distributed across different listings. It allows viewers to quickly grasp the range and frequency of reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So from the above chart we can say that if there is more number of reviews present then more than that users might be present.from this we can clearly find the frequency of reviews so we can also say that more than 40000 users are present.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it helps for creating a positive business impact and i found that more than 40000 users are present.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
minimum_nights_neighbourhood = df.groupby('neighbourhood')['minimum_nights'].mean().reset_index()
sorted_minimum_nights_neighbourhood = minimum_nights_neighbourhood.sort_values(by='minimum_nights', ascending=False)
print(sorted_minimum_nights_neighbourhood.head(10))
# Out:
#                   neighbourhood  minimum_nights
# 184              Spuyten Duyvil       48.250000
# 146             North Riverdale       41.400000
# 6             Battery Park City       30.328571
# 149                   Olinville       23.500000
# 204                Vinegar Hill       18.352941
# 9    Bay Terrace, Staten Island       16.500000
# 136                  Mount Hope       15.950000
# 92            Greenwich Village       15.839286
# 137                 Murray Hill       15.589691
# 38            Claremont Village       15.214286

# %%
plt.figure(figsize=(10, 6))
plt.bar(sorted_minimum_nights_neighbourhood['neighbourhood'][:10],
        sorted_minimum_nights_neighbourhood['minimum_nights'][:10],
        color='skyblue')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Minimum Nights')
plt.title('Average Minimum Nights Required for Booking by Neighbourhood (Top 10)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are excellent for comparing values across different categories, in this case, the average minimum nights required for booking across different neighborhoods. Each bar represents a neighborhood, and the height of the bar indicates the average minimum nights, making it easy to compare

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart I found like spuyten duyvil allows users to stay for maximum nights. So if a person or family wish to stay for more number of nights then then this area is suitable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the average minimum nights required for booking in different neighborhoods can help hosts or property managers optimize their pricing strategies. They can adjust prices based on demand and booking patterns, potentially increasing revenue.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
max_listings_count_by_host_neighbourhood = df.groupby(['host_name', 'room_type'])['calculated_host_listings_count'].max().reset_index()
sorted_max_listings_count_by_host_neighbourhood = max_listings_count_by_host_neighbourhood.sort_values(by='calculated_host_listings_count', ascending=False)
sorted_max_listings_count_by_host_neighbourhood.head(10)
# Out:
#                host_name        room_type  calculated_host_listings_count
# 12509       Sonder (NYC)     Private room                             327
# 12508       Sonder (NYC)  Entire home/apt                             327
# 1744          Blueground  Entire home/apt                             232
# 6860                Kara  Entire home/apt                             121
# 7045              Kazuya  Entire home/apt                             103
# 7046              Kazuya     Private room                             103
# 6171      Jeremy & Laura  Entire home/apt                              96
# 12507             Sonder  Entire home/apt                              96
# 6172      Jeremy & Laura     Private room                              96
# 2760   Corporate Housing  Entire home/apt                              91

# %%
plt.figure(figsize=(10,6))
plt.bar(sorted_max_listings_count_by_host_neighbourhood['room_type'],sorted_max_listings_count_by_host_neighbourhood['calculated_host_listings_count'],color='green')
plt.xlabel('room type')
plt.ylabel('Calculated host listing count')
plt.title('room type and host name vs calculated host listing count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are excellent for comparing values across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this I got the more room type like entire home or appartment and private room got listed by the host sonder nyc, so by this I can say that in the role of listings sonder nyc had palyed a very important role.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it helps for creating a positive business impact like we can note the importance of host like if a host is listing more in the platform,loosing that host might leads to a negative growth.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
busy_host=df.groupby('host_name')['number_of_reviews'].max().reset_index()
sorted_busy_host=busy_host.sort_values(by='number_of_reviews',ascending=False)
sorted_busy_host.head(10)
# Out:
#       host_name  number_of_reviews
# 2652       Dona                629
# 4931         Jj                607
# 6981       Maya                543
# 1673      Carol                540
# 2290   Danielle                510
# 936         Asa                488
# 10830     Wanda                480
# 6153      Linda                474
# 2273       Dani                467
# 661      Angela                466

# %%
plt.figure(figsize=(10, 6))
plt.bar(sorted_busy_host['host_name'][:10], sorted_busy_host['number_of_reviews'][:10], color='skyblue')
plt.xlabel('Host Name')
plt.ylabel('Number of Reviews')
plt.title('Top 10 Hosts by Maximum Number of Reviews')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are excellent for comparing values across different categories, in this case, comparing the number of reviews for each of the top 10 hosts. Each bar represents a host, and the height of the bar indicates the number of reviews, making it easy to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart i found the busy host who has more number of customers in the platform. And from this chart i found Dona who have more than 600 customers in the platform followed by jj amd maya.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# i gained the insights like dona,jj and maya the hosts who brings more customers to the platform, so we should not loose this hosts in any case.And loosing this hosts will lead to a negative growth.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
grouped = df.groupby(['neighbourhood_group', 'room_type']).size().unstack(fill_value=0)

# Plot stacked bar chart
grouped.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Room Types by Neighbourhood groups')
plt.xlabel('Neighbourhood groups')
plt.ylabel('Count')
plt.legend(title='Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked bar charts allow for easy comparison of the distribution of room types within each neighborhood group. Each bar represents a neighborhood group, and the segments within each bar represent different room types. This makes it straightforward to compare the proportion of each room type across different neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart I found in Bronex,Brooklyn and Queens private rooms are more listed and in Manhattan Entire home or appartments are more.So i belive this will be helpful for a person who is willing to stay in this area and can easily decide the area were they wants to stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So if a person who wish to book a resort in some area they can easily get idea about in which area which types of rooms are avilable more.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
more_preferred_area = df.groupby(['neighbourhood'])['number_of_reviews'].max().reset_index()
sorted_more_preferred_area = more_preferred_area.sort_values(by='number_of_reviews', ascending=False)
top_5_preferred_areas = sorted_more_preferred_area.head(5)
print(top_5_preferred_areas)
# Out:
#        neighbourhood  number_of_reviews
# 105          Jamaica                629
# 94            Harlem                607
# 59     East Elmhurst                543
# 119  Lower East Side                540
# 151       Park Slope                488

# %%
plt.figure(figsize=(10,6))
plt.bar(x='neighbourhood',height='number_of_reviews',data=top_5_preferred_areas,color='red')
plt.xlabel('neighbourhood')
plt.ylabel('Number of Reviews')
plt.title('more prefered area')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# charts are effective for comparing values across different categories. In this case, each bar represents a neighborhood, and the height of the bar indicates the number of reviews in that neighborhood. This makes it easy to compare the popularity of different areas based on the number of reviews they receive.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the neighborhoods that receive the highest number of reviews, indicating their popularity among guests. These areas are likely to be in high demand and attract a significant number of visitors.
# Over time, the number of reviews in each neighborhood may fluctuate, reflecting changing trends in guest preferences or shifts in tourism patterns. Analyzing such trends can help hosts and property managers adapt their strategies to meet evolving demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Knowing which neighborhoods are the most preferred by guests, hosts and property managers can make informed decisions about where to invest in properties or allocate resources. Investing in popular areas can lead to increased occupancy rates and higher revenue potential.
#
# If the top 5 preferred areas are already saturated with listings, hosts may face increased competition, leading to downward pressure on prices and profitability. This could result in negative growth if hosts struggle to attract enough guests to maintain occupancy rates and revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_columns = ['price', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365']
numeric_data = df[numeric_columns]

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()

# Create heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps are effective for visualizing correlation matrices because they use color gradients to represent the strength and direction of correlations between variables. The color scale allows quick interpretation: darker colors represent stronger correlations (positive or negative), while lighter colors represent weaker or no correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Price and Availability: There is a weak positive correlation between price and availability (availability_365), suggesting that higher-priced listings may have slightly higher availability throughout the year. However, the correlation is not strong, indicating that price alone may not significantly influence availability.
#
# Minimum Nights and Availability: A very weak negative correlation is observed between minimum nights and availability (availability_365). This implies that listings with higher availability might have slightly shorter minimum stay requirements, but the relationship is not significant.
#
# Number of Reviews and Host Listings: There is a weak positive correlation between the number of reviews and the calculated host listings count, indicating that hosts with a higher number of listings tend to receive more reviews. This suggests a potential relationship between the size of a host's portfolio and guest engagement.
#
# Price and Number of Reviews: There appears to be no strong correlation between price and the number of reviews, indicating that higher-priced listings do not necessarily receive more reviews. Other factors, such as listing quality and location, may have a stronger influence on the number of reviews.
#
# Minimum Nights and Number of Reviews: Similarly, there seems to be no significant correlation between minimum nights and the number of reviews, suggesting that the length of stay requirement does not strongly influence the number of reviews a listing receives.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
numeric_columns = ['number_of_reviews', 'availability_365']
numeric_data = df[numeric_columns]

# Create pair plot
sns.pairplot(numeric_data)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot visualization because it's a versatile and effective tool for exploring relationships and distributions between pairs of variables, especially when dealing with multiple numeric variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot may reveal whether there is any correlation between the number of reviews and the availability of listings. A positive correlation would suggest that listings with higher availability tend to receive more reviews, while a negative correlation would suggest the opposite. Lack of correlation indicates that the variables are independent of each other.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The insights gathered from the discussion revolve around the exploratory analysis of the Airbnb NYC 2019 dataset, which serves as a rich source of information about Airbnb listings in New York City for the year 2019. Utilizing various visualization techniques such as histograms, box plots, scatter plots, pair plots, and correlation heatmaps, the analysis delves into key numeric variables like price, minimum nights, number of reviews, calculated host listings count, and availability_365. Through these visualizations, relationships between variables are uncovered, such as the correlation between the number of reviews and listing availability. Additionally, insights into the distribution and spread of data for individual variables are gained, informing understanding of market dynamics and user behaviors within the Airbnb ecosystem.
#
# With a primary business objective of leveraging these insights to inform strategic decision-making, optimize operational strategies, enhance user experiences, and support policy decisions within the Airbnb ecosystem in New York City, recommendations are made for adopting a data-driven approach to decision-making, investing in analytics tools, implementing monitoring and evaluation frameworks, and fostering collaboration among stakeholders. By following these recommendations and utilizing the insights derived from the analysis, stakeholders can work towards promoting sustainable growth and positive societal outcomes within the Airbnb market in New York City, ultimately benefiting hosts, guests, policymakers, and industry stakeholders alike.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the exploratory analysis of the Airbnb NYC 2019 dataset has provided valuable insights into the dynamics of the Airbnb ecosystem within New York City. Through visualizations and statistical analysis, we have gained a deeper understanding of key variables such as listing prices, availability, host behaviors, guest preferences, and spatial-temporal trends. These insights can inform strategic decision-making, optimize operational strategies, and enhance user experiences for hosts, guests, policymakers, and industry stakeholders.
#
# The analysis highlighted the importance of data-driven decision-making, technological investment, continuous monitoring, and stakeholder collaboration in navigating the complexities of the Airbnb market. By leveraging these insights, stakeholders can adapt their strategies, improve their offerings, and contribute to the sustainable growth of the Airbnb ecosystem while addressing regulatory and societal concerns.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
